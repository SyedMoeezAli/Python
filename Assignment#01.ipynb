# %% [markdown]
# # Q1:-Find the total number of patients of each disease (diagnosis) and plot in histogram.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
df=pd.read_csv('jsrt_metadata.csv')

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
df=df.dropna()

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y      state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# ..            ...       ...   ...  ..     ...     ...     ...        ...
# 149  JPCLN150.png       1.0  15.0  51  Female  1544.0  1409.0  malignant
# 150  JPCLN151.png       1.0  14.0  37  Female  1520.0  1364.0  malignant
# 151  JPCLN152.png       1.0  10.0  56    Male  1323.0  1438.0     benign
# 152  JPCLN153.png       1.0  10.0  64    Male  1708.0  1122.0  malignant
# 153  JPCLN154.png       1.0   8.0  75  Female   660.0   688.0  malignant
#
#                position                     diagnosis
# 0          l.upper lobe                   lung cancer
# 1      l.upper lobe(S5)            pulmonary hematoma
# 2    l.upper lobe(S1+2)                   lung cancer
# 3          r.upper lobe             Inflammatory mass
# 4      l.upper lobe(S3)                   lung cancer
# ..                  ...                           ...
# 149    l.lower lobe(S8)   lung cancer(adenocarcinoma)
# 150        l.lower lobe  metastasis of uterine cancer
# 151   l.lower lobe(S10)               susp. hamartoma
# 152        l.lower lobe                   lung cancer
# 153    r.upper lobe(S1)         susp. lung metastasis
#
# [154 rows x 10 columns]

# %%
plt.pyplot.title("Total Number of Patients of each Disease")
plt.pyplot.xlabel("Diagnosis")
plt.pyplot.ylabel("No. of Patients")
plt.pyplot.hist(df['diagnosis'].value_counts())
# Out:
# (array([27.,  2.,  1.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 1. ,  6.5, 12. , 17.5, 23. , 28.5, 34. , 39.5, 45. , 50.5, 56. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Q2:-Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in a pie chart.

# %%
disease_state=df.groupby('state')["diagnosis"].count()
disease_state
# Out:
# state
# benign        54
# malignant    100
# Name: diagnosis, dtype: int64

# %%
disease_state.plot(kind='pie',explode=[0,0.1])
# Out:
# <AxesSubplot:ylabel='diagnosis'>

# %%
mal = df.loc[df["state"] == "malignant"]
mal=mal.groupby('diagnosis').count()
plt.pyplot.pie(mal['x'],shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22831a43970>,
#   <matplotlib.patches.Wedge at 0x22831a513a0>,
#   <matplotlib.patches.Wedge at 0x22831a51d30>,
#   <matplotlib.patches.Wedge at 0x22831a5d730>,
#   <matplotlib.patches.Wedge at 0x22831a6c100>,
#   <matplotlib.patches.Wedge at 0x22831a6ca90>,
#   <matplotlib.patches.Wedge at 0x22831a79460>,
#   <matplotlib.patches.Wedge at 0x22831a79df0>,
#   <matplotlib.patches.Wedge at 0x22831a877c0>,
#   <matplotlib.patches.Wedge at 0x22831a95190>,
#   <matplotlib.patches.Wedge at 0x22831a1b7c0>,
#   <matplotlib.patches.Wedge at 0x22831aa44c0>,
#   <matplotlib.patches.Wedge at 0x22831aa4e50>],
#  [Text(-0.20611945413751356, 1.080515974257694, ''),
#   Text(-0.4993895221842246, -0.9801071906340714, ''),
#   Text(0.3068902594174457, -1.0563230418175555, ''),
#   Text(0.559945595886998, -0.9468162068990765, ''),
#   Text(0.7778174911659316, -0.7778174274444717, ''),
#   Text(0.8251222053691912, -0.7274430192164074, ''),
#   Text(0.8899187180267094, -0.6465637441936395, ''),
#   Text(0.9468162494951095, -0.5599455238610405, ''),
#   Text(1.0227541473674753, -0.4049369753957138, ''),
#   Text(1.0735084449287227, -0.2399575351321897, ''),
#   Text(1.0864571792865916, -0.17207788229933355, ''),
#   Text(1.0951181637045018, -0.10351911671029705, ''),
#   Text(1.099457217235311, -0.0345518084792481, '')],
#  [Text(-0.11242879316591647, 0.5893723495951058, '56.0%'),
#   Text(-0.27239428482775885, -0.5346039221640388, '23.0%'),
#   Text(0.16739468695497034, -0.5761762046277574, '1.0%'),
#   Text(0.30542487048381706, -0.5164452037631326, '7.0%'),
#   Text(0.4242640860905081, -0.42426405133334816, '1.0%'),
#   Text(0.45006665747410424, -0.3967871013907676, '1.0%'),
#   Text(0.4854102098327505, -0.3526711331965306, '2.0%'),
#   Text(0.5164452269973323, -0.3054248311969311, '1.0%'),
#   Text(0.5578658985640773, -0.22087471385220753, '4.0%'),
#   Text(0.5855500608702122, -0.13088592825392165, '1.0%'),
#   Text(0.5926130068835953, -0.09386066307236374, '1.0%'),
#   Text(0.5973371802024555, -0.05646497275107111, '1.0%'),
#   Text(0.5997039366738058, -0.01884644098868078, '1.0%')])

# %%
bgn = df.loc[df["state"] == "benign"]
bgn=bgn.groupby('diagnosis').count()
plt.pyplot.pie(bgn['y'],shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22831afa760>,
#   <matplotlib.patches.Wedge at 0x22831b09190>,
#   <matplotlib.patches.Wedge at 0x22831b09b20>,
#   <matplotlib.patches.Wedge at 0x22831b1a4f0>,
#   <matplotlib.patches.Wedge at 0x22831b1ae80>,
#   <matplotlib.patches.Wedge at 0x22831b25850>,
#   <matplotlib.patches.Wedge at 0x22831b34220>,
#   <matplotlib.patches.Wedge at 0x22831b34be0>,
#   <matplotlib.patches.Wedge at 0x22831b425b0>,
#   <matplotlib.patches.Wedge at 0x22831b42f40>,
#   <matplotlib.patches.Wedge at 0x22831ad8490>,
#   <matplotlib.patches.Wedge at 0x22831b5e2b0>,
#   <matplotlib.patches.Wedge at 0x22831b5ec40>,
#   <matplotlib.patches.Wedge at 0x22831b6b610>,
#   <matplotlib.patches.Wedge at 0x22831b6bfa0>,
#   <matplotlib.patches.Wedge at 0x22831b7a970>,
#   <matplotlib.patches.Wedge at 0x22831b87340>,
#   <matplotlib.patches.Wedge at 0x22831b87cd0>,
#   <matplotlib.patches.Wedge at 0x22831b946a0>],
#  [Text(1.0925621934054306, 0.12770220648491118, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(0.9526279420172694, 0.550000003716311, ''),
#   Text(0.5499999925673781, 0.9526279484541089, ''),
#   Text(-0.06395932512941842, 1.0981389733221336, ''),
#   Text(-0.43568775752854877, 1.0100377111473338, ''),
#   Text(-0.7548658155281622, 0.8001109926422725, ''),
#   Text(-0.8823355242738076, 0.656874434427513, ''),
#   Text(-0.9526279548909481, 0.549999981418445, ''),
#   Text(-1.010037726444345, 0.4356877220660905, ''),
#   Text(-1.0703493631357222, 0.2536774346191521, ''),
#   Text(-1.0981389725735955, -0.06395933798131731, ''),
#   Text(-1.0336618730799265, -0.3762221845411272, ''),
#   Text(-0.95262792914359, -0.5500000260141771, ''),
#   Text(-0.8426488672029966, -0.7070663947618405, ''),
#   Text(-0.7070663454527888, -0.8426489085782036, ''),
#   Text(-0.6044598475941111, -0.9190366111567614, ''),
#   Text(0.31548357059890925, -1.053788459171082, ''),
#   Text(1.070349357197973, -0.25367745967248734, '')],
#  [Text(0.5959430145847803, 0.06965574899176973, '3.7%'),
#   Text(0.563815571937841, 0.20521208746174077, '3.7%'),
#   Text(0.5196152411003288, 0.3000000020270787, '1.9%'),
#   Text(0.29999999594584253, 0.519615244611332, '14.8%'),
#   Text(-0.034886904616046405, 0.5989848945393456, '3.7%'),
#   Text(-0.23764786774284474, 0.5509296606258183, '7.4%'),
#   Text(-0.4117449902880884, 0.43642417780487586, '3.7%'),
#   Text(-0.4812739223311677, 0.35829514605137075, '1.9%'),
#   Text(-0.5196152481223353, 0.29999998986460635, '1.9%'),
#   Text(-0.5509296689696426, 0.23764784839968572, '1.9%'),
#   Text(-0.5838269253467575, 0.13836950979226478, '3.7%'),
#   Text(-0.5989848941310519, -0.03488691162617308, '5.6%'),
#   Text(-0.5638155671345053, -0.20521210065879666, '3.7%'),
#   Text(-0.5196152340783218, -0.30000001418955113, '1.9%'),
#   Text(-0.459626654837998, -0.3856725789610039, '3.7%'),
#   Text(-0.3856725520651575, -0.4596266774062928, '1.9%'),
#   Text(-0.32970537141496964, -0.501292696994597, '1.9%'),
#   Text(0.172081947599405, -0.5747937050024083, '25.9%'),
#   Text(0.5838269221079851, -0.13836952345772036, '7.4%')])

# %%
df['diagnosis'].value_counts()
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# susp. hamartoma                                    1
# metastasis of uterine cancer                       1
# organizing pneumonia                               1
# metastasis of ovarian cancer                       1
# metastatic lung cancer                             1
# lung canceror metastasis                           1
# pneumonia                                          1
# calcified granuloma                                1
# lung cancer(adenosquamous carcinoma)               1
# lung cancer(small cell carcinoma)                  1
# susp.tuberculoma                                   1
# organiging pneumonia                               1
# susp. sclerosing hemangioma                        1
# susp. lung metastasis                              1
# Name: diagnosis, dtype: int64

# %%
plt.pyplot.pie(df['diagnosis'].value_counts(),shadow=True,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x22831bdae50>,
#   <matplotlib.patches.Wedge at 0x22831acf880>,
#   <matplotlib.patches.Wedge at 0x22831bf4250>,
#   <matplotlib.patches.Wedge at 0x22831bf4be0>,
#   <matplotlib.patches.Wedge at 0x22831c025b0>,
#   <matplotlib.patches.Wedge at 0x22831c02f40>,
#   <matplotlib.patches.Wedge at 0x22831c12910>,
#   <matplotlib.patches.Wedge at 0x22831c1e2e0>,
#   <matplotlib.patches.Wedge at 0x22831c1ec70>,
#   <matplotlib.patches.Wedge at 0x22831c2d640>,
#   <matplotlib.patches.Wedge at 0x22831bb6ac0>,
#   <matplotlib.patches.Wedge at 0x22831c3b970>,
#   <matplotlib.patches.Wedge at 0x22831c46370>,
#   <matplotlib.patches.Wedge at 0x22831c46d00>,
#   <matplotlib.patches.Wedge at 0x22831c576d0>,
#   <matplotlib.patches.Wedge at 0x22831c630a0>,
#   <matplotlib.patches.Wedge at 0x22831c63a30>,
#   <matplotlib.patches.Wedge at 0x22831c71400>,
#   <matplotlib.patches.Wedge at 0x22831c71d90>,
#   <matplotlib.patches.Wedge at 0x22831c7f760>,
#   <matplotlib.patches.Wedge at 0x22831c8c130>,
#   <matplotlib.patches.Wedge at 0x22831c8cac0>,
#   <matplotlib.patches.Wedge at 0x22831c9c490>,
#   <matplotlib.patches.Wedge at 0x22831c9ce20>,
#   <matplotlib.patches.Wedge at 0x22831ca86d0>,
#   <matplotlib.patches.Wedge at 0x22831cb90a0>,
#   <matplotlib.patches.Wedge at 0x22831cb9a30>,
#   <matplotlib.patches.Wedge at 0x22831cc7400>,
#   <matplotlib.patches.Wedge at 0x22831cc7d90>,
#   <matplotlib.patches.Wedge at 0x22831cd3760>,
#   <matplotlib.patches.Wedge at 0x22831cde130>,
#   <matplotlib.patches.Wedge at 0x22831cdeac0>],
#  [Text(-1.0005952104475537, 0.4569564802357176, ''),
#   Text(-0.41576332203954086, -1.0184011292445847, ''),
#   Text(0.39490300853154947, -1.026670158255674, ''),
#   Text(0.8012508099325273, -0.7536558495642884, ''),
#   Text(0.9910657786312884, -0.47727206332023897, ''),
#   Text(1.072420716700226, -0.24477296907986795, ''),
#   Text(1.0979406641581488, -0.06727776741214977, ''),
#   Text(1.0942827800907242, 0.1120053445015718, ''),
#   Text(1.067204537151858, 0.2665979667636061, ''),
#   Text(1.0345119759925845, 0.37387828437597, ''),
#   Text(1.0005951716751365, 0.45695656513546723, ''),
#   Text(0.9600195715891694, 0.5369938753521756, ''),
#   Text(0.9130551996582495, 0.6134575799328217, ''),
#   Text(0.8600145960284202, 0.6858388255399903, ''),
#   Text(0.801250737165097, 0.7536559269271282, ''),
#   Text(0.7371546868529328, 0.8164575724743783, ''),
#   Text(0.6681529937308563, 0.8738258275929445, ''),
#   Text(0.6134574877677966, 0.9130552615814794, ''),
#   Text(0.5757047349640217, 0.9373174799074248, ''),
#   Text(0.5369937784465039, 0.9600196257940496, ''),
#   Text(0.49738904878189527, 0.9811239137600518, ''),
#   Text(0.4569564641340403, 1.0005952178009425, ''),
#   Text(0.41576332054970383, 1.0184011298528122, ''),
#   Text(0.37387817995093553, 1.034512013732357, ''),
#   Text(0.3313707560205234, 1.0489010544633783, ''),
#   Text(0.2883117981704468, 1.0615443029076665, ''),
#   Text(0.24477297378645899, 1.0724207156259775, ''),
#   Text(0.20082674894480296, 1.0815121899027589, ''),
#   Text(0.1565462677995761, 1.0888035938763354, ''),
#   Text(0.1120052308415017, 1.094282791724398, ''),
#   Text(0.0672777722307416, 1.0979406638628832, ''),
#   Text(0.02243833640790017, 1.09977112212462, '')],
#  [Text(-0.5457792056986657, 0.2492489892194823, '36.4%'),
#   Text(-0.2267799938397495, -0.5554915250425007, '14.9%'),
#   Text(0.21540164101720877, -0.560001904503095, '9.1%'),
#   Text(0.437045896326833, -0.41108500885324817, '5.2%'),
#   Text(0.5405813337988845, -0.26033021635649395, '4.5%'),
#   Text(0.5849567545637595, -0.13351252858901885, '2.6%'),
#   Text(0.5988767259044447, -0.03669696404299078, '2.6%'),
#   Text(0.5968815164131223, 0.06109382427358461, '2.6%'),
#   Text(0.5821115657191952, 0.14541707278014876, '1.9%'),
#   Text(0.5642792596323187, 0.20393360965961996, '1.3%'),
#   Text(0.5457791845500743, 0.24924903552843664, '1.3%'),
#   Text(0.5236470390486377, 0.2929057501920957, '1.3%'),
#   Text(0.4980301089044997, 0.33461322541790267, '1.3%'),
#   Text(0.46909887056095645, 0.3740939048399947, '1.3%'),
#   Text(0.4370458566355074, 0.41108505105116083, '1.3%'),
#   Text(0.4020843746470542, 0.4453404940769336, '1.3%'),
#   Text(0.364447087489558, 0.47663226959615146, '1.3%'),
#   Text(0.33461317514607086, 0.4980301426808069, '0.6%'),
#   Text(0.31402076452583, 0.5112640799495043, '0.6%'),
#   Text(0.29290569733445665, 0.5236470686149362, '0.6%'),
#   Text(0.2713031175173974, 0.5351584984145736, '0.6%'),
#   Text(0.24924898043674923, 0.5457792097096049, '0.6%'),
#   Text(0.22677999302711116, 0.5554915253742612, '0.6%'),
#   Text(0.20393355270051025, 0.5642792802176492, '0.6%'),
#   Text(0.18074768510210368, 0.5721278478891153, '0.6%'),
#   Text(0.15726098082024367, 0.5790241652223636, '0.6%'),
#   Text(0.13351253115625034, 0.5849567539778058, '0.6%'),
#   Text(0.1095418630608016, 0.5899157399469593, '0.6%'),
#   Text(0.08538887334522331, 0.593892869387092, '0.6%'),
#   Text(0.06109376227718273, 0.5968815227587625, '0.6%'),
#   Text(0.0366969666713136, 0.5988767257433908, '0.6%'),
#   Text(0.012239092586127365, 0.59987515752252, '0.6%')])

# %% [markdown]
# # Q3:-Find and plot via pia chart the total number of patients of each disease (diagnosis) with respect to the gender(Female, Male)

# %%
df['gender'].value_counts()
# Out:
# Female    86
# Male      68
# Name: gender, dtype: int64

# %%
plt.pyplot.pie(df['gender'].value_counts(),explode=[0,0.1],shadow=True,labels=['Female','Male'],autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x22831d34310>,
#   <matplotlib.patches.Wedge at 0x22831d34d60>],
#  [Text(-1.0815121666930982, -0.20082687393573673, 'Female'),
#   Text(1.1798314340621723, 0.21908397293914045, 'Male')],
#  [Text(-0.5899157272871445, -0.10954193123767457, '55.8%'),
#   Text(0.6882350032029338, 0.1277989842144986, '44.2%')])

# %%
df_female= df.loc[df["gender"] == "Female"]
df_female.groupby("diagnosis")["gender"].count().plot(kind = "pie", figsize = (10,10),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
df_male= df.loc[df["gender"] == "Male"]
df_male.groupby("diagnosis")["gender"].count().plot(kind = "pie", figsize = (10,10),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='gender'>
